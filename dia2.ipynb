# %%
#valet parking, yo tengo que ir a buscaar el auto, marca, color, chapa,

#que necesito: el auto, la marca, color, chapa

def valet_busca_auto(marca, color, chapa):
    
    #informacion para el valet parking
    print("Vehiculo a buscar: ")
    print(f"vehiculo: {marca}")
    print(f"color del vehiculo: {color}")
    print(F"chapa del vehiculo: {chapa}")

    #salto de linea porque no se como se hacia:
    print(" ")

    #Pasos a hacer para el valet:
    print("retirar el vehiculo")
    print("Cobrarle")
    print("retornar al dueño")

#informacion proveida por el usuario:
marca_del_vehiculo = input("ingrese la marca de su vehiculo")
color_del_vehiculo = input("ingrese el color de su vehiculo")
chapa_del_vehiculo = input("ingrese la chapa de su vehiculo")

#llamar a la funcion:
valet_busca_auto(marca_del_vehiculo, color_del_vehiculo, chapa_del_vehiculo)
# Out:
# Vehiculo a buscar:
# vehiculo: toyota
# color del vehiculo: negro
# chapa del vehiculo: sienta
#
# retirar el vehiculo
# Cobrarle
# retornar al dueño

# %%
#comparaciones
edad_1 = 20
edad_2 = 19

nombre_1 = "Ana"
nombre_2 = "lucia"

print(nombre_1 == nombre_2)
print(edad_1 > edad_2)

#condiciona:

#1era condicional:
if edad_1 >= 18:
    print("es menor de edad")
else:
    print("es mayor de edad")

#2da condicional:
if nombre_1 == nombre_2:
    print("los nombres estan repetidos")
else:
    print("son nombre diferentes")

#3ra condicional:
# Out:
# False
# True
# es menor de edad
# son nombre diferentes

# %%
#challenge 
#Escribe un programa que pregunte al usuario por su edad y determine si tiene edad suficiente para comprar y consumir alcohol.
#Si el usuario tiene mas de 18 pero menos de 21 impirmir "Podes tomar pero no comprar"
#Si el usuario tiene menos de 18 imprimir "Juguito nomas"
#Si el usuario tiene mas de 21 imprimir "Hace lo que quieras"

#descomposicion:
# necesito pedirle al usuario datos, 
# necesito de alguna forma determinar si tiene la edad suficiente para tomar, 
# necetio mostrar diferentes dialogos segun ciertas condiciones
# necesito mostrar esa informacion en la pantalla

#como voy a hacer
#puedo pedir al usuario sus datos con un input y luego utilizarlos

#como puedo determinar si tiene la edad suficiente para cumplir las condiciones para cietas lineas de codigo
#con condicionales
#creo que es mejor hacer dentro de una funcion, y dentro de la funcion poder mis condicionales

#codigo completo:

def edad_suficiente_alcohol(nombre, edad):
    print(f"estimado {nombre}")

    if 21 > edad >= 18 :
        print(f"como tiene una edad de {edad} usted tiene permitido tomar pero no comprar")
    elif 18 > edad:
        print(f"usted tiene una edad de {edad} años, y solo puede tomar juguito")
    else:
        print(f"Usted tiene una edad de {edad} puede hace lo que quieras")

    
nombre_usuario = input("Introduzca su nombre: ")
edad_usuario = int(input("introduzca tu edad"))


edad_suficiente_alcohol(nombre_usuario, edad_usuario)
# Out:
# estimado ivan
# Usted tiene una edad de 22 puede hace lo que quieras

# %%
# CHALLENGE 
# Escribir un programa en el que se pregunte al usuario por una temperatura (en grados Celsius), 
# imprima la temperatura escrita, y luego clasificar la temperatura ingresada en los siguientes niveles:

# Entre -10 y 18 grados, que imprima "Fresquete".
# Entre 19 y 30 grados, que imprima "Calor'i".
# Entre 31 y 45 grados, que imprima "Hakuuuuuu".
# Para todo lo demás, imprimir "Ñamano mba'e!".

# problema : hacer un programa que pregunte al usuario por temperatura, clasificar la temperatura, condicionar,
# mostrar un mensaje diferente dependiendo de la condicion que cumple

# - preguntar al usuario 
# temperatura_usuario = int(input("Cual es la temperatura de hoy?: "))


# - clasificar y condicionar

# if temperatura_usuario >= -10 and temperatura_usuario <= 18:
#     print("hace un fresqueteee")

# elif temperatura_usuario >=19 and temperatura_usuario <= 30:
#     print("che, ya hace calor'i... ")

# elif temperatura_usuario >= 31 and temperatura_usuario <= 45:
#     print("hakuuuuuuuu")

# else:
#     print("Diomio, Ñamano mba'e ")


# - hacer funcion para que se pueda usar en otros lados si necesario y meter a dentro mis condicionales y clasificacion:
#  tambien mostrar la temperatura

# def temperatura_afuera(temperatura):
#     if temperatura_usuario >= -10 and temperatura_usuario <= 18:
#         print(f"hace un fresqueteee \nla temperatura es de {temperatura} Celsius")

#     elif temperatura_usuario >=19 and temperatura_usuario <= 30:
#         print("che, ya hace calor'i... \nla temperatura es de {temperatura} Celsius")

#     elif temperatura_usuario >= 31 and temperatura_usuario <= 45:
#         print("hakuuuuuuuu \nla temperatura es de {temperatura}")

#     else:
#         print("Diomio, Ñamano mba'e \nla temperatura es de {temperatura}")


#codigo completo

def temperatura_afuera(temperatura):
    if temperatura >= -10 and temperatura <= 18:
        print(f"hace un fresqueteee \nla temperatura es de {temperatura} Celsius")

    elif temperatura >=19 and temperatura <= 30: 
        print(f"che, ya hace calor'i... \nla temperatura es de {temperatura} Celsius ")

    elif temperatura >= 31 and temperatura <= 45:
        print(f"hakuuuuuuuu \nla temperatura es de {temperatura} Celsius")

    else:
        print(f"Diomio, Ñamano mba'e \nla temperatura es de {temperatura}")



temperatura_usuario = int(input("Cual es la temperatura de hoy?: "))


temperatura_afuera(temperatura_usuario)
# Out:
# che, ya hace calor'i...
# la temperatura es de 30 Celsius

# %%
#CHALLENGE:
# Escribir un programa que almacene una contraseña en una variable,
# y pregunte al usuario por la contraseña hasta que introduzca la contraseña correcta.

# Cuando el usuario ingrese la contrasena correcta, imprimir un mensaje secreto.

# problema principal : programa que almacene una contraseña, la contraseña se le pregunte al usuario y luego que el usuario introduzca
# una contraseña hasta que le atine a su contraseña, mostrar un mensaje secreto

# por problemas:
# Almacenar una contraseña en una variable:
# contraseña_usuario = input("instroduzca una contraseña: ")

# preguntar la contraseña
# contraseña_introducida = input("introduzca su contraseña de nuevo: ")

#preguntar por la contraseña multiples veces hasta acertar:
# (con while inicio un bucle infinito y luego con una condiciona verifico si es que la contraseña introducida por seguda vez 
# es correcta)
# while True:

#     if contraseña_usuario == contraseña_introducida:
#         print("la contraseña se actualizo.")
#         break

#     else:
#         print("las contraseñas no coinciden.")
#         contraseña_introducida = input("introduzca otra vez la contraseña: ")

# codigo completo:

contraseña_usuario = input("instroduzca una contraseña: ")
contraseña_introducida = input("introduzca su contraseña de nuevo: ")

while True:

    if contraseña_usuario == contraseña_introducida:
        print("la contraseña se actualizo.")
        break

    else:
        print("las contraseñas no coinciden.")
        contraseña_introducida = input("introduzca otra vez la contraseña: ")
# Out:
# la contraseña se actualizo.

# %%
#challenge
#Crear una lista de 5 elementos. Luego, seguir los siguientes pasos.

# Agregar un elemento al final de la lista.
# Modificar el segundo elemento.
# Eliminar el tercer elemento.

#problema : crear una lista, agregar 5 elementos, seguir los pasos listados, mostrar mientras se hace el proceso por la panatalla

#crear la lista:
# autos = ['toyota', 'ford', 'nissan', 'audi', 'BMW']
# print(autos)

#seguir cada paso y mostrar en pantalla
#agregar un elemento al final de la lista:
# autos.append('KIA')
# print(autos)

#modificar el segundo elemento:
# autos[1] = 'Tesla'
# print(autos)

#Eliminar el tercer elemento: (elegi pop)
# autos.pop(2)
# print(autos)

#situacion ipotetica
#quiero quitar por remove
# autos.remove('audi')
# print(autos)


#codigo completo:

autos = ['toyota', 'ford', 'nissan', 'audi', 'BMW']
print(autos)

autos.append('KIA')
print(autos)

autos[1] = 'Tesla'
print(autos)

autos.pop(2)
print(autos)

autos.remove('audi')
print(autos)
# Out:
# ['toyota', 'ford', 'nissan', 'audi', 'BMW']
# ['toyota', 'ford', 'nissan', 'audi', 'BMW', 'KIA']
# ['toyota', 'Tesla', 'nissan', 'audi', 'BMW', 'KIA']
# ['toyota', 'Tesla', 'audi', 'BMW', 'KIA']
# ['toyota', 'Tesla', 'BMW', 'KIA']

# %%
#challenge
#Escribir un programa que itere en un rango de 10 veces. 
# Por cada iteracion multiplicar el iterador por dos e imprimir el resultado.

#problema : hacer un programa que itere en un rango 10 veces, multiplicar el iterador por dos, mostrarlo en pantalla

# programa que itere en un rango de 10 veces
# for i in range(10):

#multiplicar el iterador por dos (almacenado en una variable asi se puede llamar despues)
# iterador_dos = i * 2

#printear los resultados en pantalla:
# print(f"el iterador multiplicado por dos es: {iterador_dos}")

#codigo completo:

for i in range(10):
    iterador_dos = i * 2
    print(f"el iterador multiplicado por dos es: {iterador_dos}")
# Out:
# el iterador multiplicado por dos es: 0
# el iterador multiplicado por dos es: 2
# el iterador multiplicado por dos es: 4
# el iterador multiplicado por dos es: 6
# el iterador multiplicado por dos es: 8
# el iterador multiplicado por dos es: 10
# el iterador multiplicado por dos es: 12
# el iterador multiplicado por dos es: 14
# el iterador multiplicado por dos es: 16
# el iterador multiplicado por dos es: 18

# %%
#challenges
#Recorrer los elementos de una lista de marcas e imprimir cada marca solamente si tiene 6 letras o más.
#problema : recorrer los elementos de una lista, imprimir cada marca que tiene 6 letras o mas, mostrar en pantalla

#mini problemas:
# crear un alista
# la marcas que tendra la lista
# poder identificar si una marca tiene 6 o mas letras
# imprimir esas marcas

#crear la lista:
# lista_marcas = ['samsung', 'niko', 'toyota', 'BMW', 'adidas', 'nike']

#como identificar si un elemento tiene mas de 6 letras
# print(len("xiaomi")) fdb lo sabia 

# ahora iterar los elementos de una lista y ver si se puede usar como creo len:
# for marcas_mas_seis in lista_marcas:
#     if len(marcas_mas_seis) >= 6:
#         print(marcas_mas_seis)

#codigo completo

lista_marcas = ['samsung', 'niko','toyota', 'BMW', 'adidas', 'nike']

for marcas_num_letras in lista_marcas:
    if len(marcas_num_letras) >= 6:
        print(marcas_num_letras)
# Out:
# samsung
# toyota
# adidas

# %%
#challenge
#solicitar al usuario que ingrese una frase
#imprimir un mensaje cada vez que se encuentre la letra "o"

#problema : programa que pida al usuario ingresar una frase, que pueda iterar una variable a la cual se le asigno la frase, iterar 
#toda la cadena de carcarteres, imprimir una frase cada vez que se encuentre la letra "o" en la frase

#pedir al usuario una frase:

# frase_usuario = input("ingresa una frase por favor: ")

# iterar la frase por medio de un for:
# for letra in frase_usuario:

#     identificar cada letra de la frase
#     if letra == "o":

#         que imprima un mensaje una vez encontrada la letra deseada
#         print("Una o fue encontrada :) ")
    

#codigo completo:

frase_usuario = input("ingresa una frase por favor: ")

for letra in frase_usuario:
    if letra == "o":
        print(f"Una letra O fue encontrada")
# Out:
# Una letra O fue encontrada
# Una letra O fue encontrada
