# %%
# REPASO DE FUNCIONES:

def saludar():
    print('buen dia')

saludar()
# Out:
# buen dia

# %%
# challege:
# crear una funcion que imprima la variable palabra

#primero se hace la funcion 
#los parametros no son necesarios para que funcione una funcion
#los argumentos en cambio si son necesarios para su funcionamiento

def imprimir(palabra):
    print(palabra)

# asignar la variable:

palabra = input('introduzca una palabra')

# se llama a la funcion:

imprimir(palabra)
# Out:
# hola

# %%
#challenge:
#crear una funcion que reciba dos letras (parametros) y que verifique si son iguales 

#problema: funcion que reciba dos parametros, que verifique que sean iguales, y que las muestren en pantalla mensajes
# diferentes deppendiendo de condiciones

# #verificar que sean iguales e imprimir en pantalla mensajes dependiendo de condicionantes:
# if letra1 == letra2:
#     print('Las letras son iguales')
# else:
#     print('Las letras son diferentes')

# #parametros de la funcion:

# letra1 = input('ingrese una letra: ')

# letra2 = input('ingrese otra letra: ')

# #hacer la funcion 

# def verificacion_letras(letra1, letra2):
#     if letra1 == letra2:
#         print('Las letras son iguales')
#     else:
#         print('Las letras son diferentes')

# #llamar a la funcion con los parametros:
# verificacion_letras(letra1, letra2)


# codigo completo:

def verificacion_letras(letra1, letra2):
    if letra1 == letra2:
        print('Las letras son iguales')
    else:
        print('Las letras son diferentes')


letra1 = input('ingrese una letra: ')
letra2 = input('ingrese otra letra: ')


verificacion_letras(letra1, letra2)
# Out:
# Las letras son diferentes

# %%
#challenge
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es 
# igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.
# Pista: cantidad de letras de una palabra en python

#problema: crear un programa, que tenga una funcion, que la funcion reciba parametros, que condicione los dos parametros
# que cada condicion retorne un valor booleano diferente

# definir los parametros que necesito:
# palabra = input('ingrese una palabra')
# numero = int(input('ingrese la cantidad de letras que crees que tenga la palabra'))

# prueba de numero y palabra
# cant_letra_palabra = len(palabra)
# if cant_letra_palabra == numero:
#     print('funciona')

#condicionar los argumentos y retornar diferente valores booleanos
# if cant_letra_palabra == numero:
#     return True
# else:
#     return False

#crear la funcion y poner dentro la condicional con los return
# def verificador(palabra, numero):

#     cant_letra_palabra = len(palabra)
#     if cant_letra_palabra == numero:
#         return True
#     else:
#         return False

#asignar el resultado de la funcion a una variable para poder imprimir
# num_imprimir = verificador(palabra, numero)
# print(num_imprimir)
    
#codigo completo:

def verificador(palabra, numero):

    cant_letra_palabra = len(palabra)
    if cant_letra_palabra == numero:
        return True
    else:
        return False

palabra = input('ingrese una palabra')
numero = int(input('ingrese la cantidad de letras que crees que tenga la palabra'))

num_imprimir = verificador(palabra, numero)

print(num_imprimir)
# Out:
# True

# %%
#challenge
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). 
# Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
# Ejemplo del resultado esperado:

# [['c', 'i', 'e', 'l', 'o']]
#  # Al ingresar la primera palabra

# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
#  # Al ingresar la segunda palabra

# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
#  # Al ingresar la tercera palabra

#problemas: pedir al usuario que ingrese palabra, convertir a lista, agregar el resultado a lista de caracteres, 
# que se repita tres veces, mostrar en la pantalla

#pedir al usuario que ingrese palabra:
# palabra_del_usuario = input('escriba una palabra')

#convertir la palabra a lista:
# palabra_convertida_a_lista = list(palabra_del_usuario)

#agregar el resultado a una lista de caracteres 
# palabras_ingresadas = []
# palabras_ingresadas.append(palabra_convertida_a_lista)
# print(palabras_ingresadas) (funciona)

#que el proceso se repita tres veces
# for veces_a_ingresar in range(3):

#     palabra_del_usuario = input('escriba otra palabra:')
#     palabra_convertida_a_lista = list(palabra_del_usuario)

#     palabras_ingresadas.append(palabra_convertida_a_lista)

#     print(palabras_ingresadas)

#codigo completo:

palabras_ingresadas = []

for veces_a_ingresar in range(3):

    palabra_del_usuario = input('escriba otra palabra:')
    palabra_convertida_a_lista = list(palabra_del_usuario)

    palabras_ingresadas.append(palabra_convertida_a_lista)

    print(palabras_ingresadas)
# Out:
# [['c', 'o', 'm', 'o']]
# [['c', 'o', 'm', 'o'], ['e', 's', 't', 'a', 's']]
# [['c', 'o', 'm', 'o'], ['e', 's', 't', 'a', 's'], ['d', 'i', 'a']]

# %%
#challenge:
# Dada la lista de ejemplo: 

# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.

# Ejemplo del resultado esperado:


# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# Problemas: crear una lista de listas - hacer que palabras que yo quiera se conviertan a lista - agregar esa nueva lista a la lista
# - repetir el proceso unas 5 veces - hacer que cada lista de la lista se imprima - que las impresiones sean una abajo de la otra - 
# - que se una funcion.

#crear una lista de listas

# lista_de_listas = []

# #hacer que palabras que yo quier se comviertan a lista:

# palabra_a_convertir = input('ingrese una palabra: ')
# palabra_convertida = list(palabra_a_convertir)

# #agregar esa nueva lista a la lista de listas:
# lista_de_listas.append(palabra_convertida)

#hacer que el proceso se repita 5 veces:
# for convertir_palabras in range(5):
#     palabra_a_convertir = input('ingrese una palabra: ')
#     palabra_convertida = list(palabra_a_convertir)
#     lista_de_listas.append(palabra_convertida)

# #hacer que la lista se imprima
# print(lista_de_listas)

# #imprimir una de bajo de la otra:
# for impresion in range(len(lista_de_listas)):
#     print(lista_de_listas[impresion])

# #que sea una funcion
# def generador_de_listas_que_estan_dentro_de_otra_lista():
#     lista_de_listas = []

#     for convertir_palabras in range(5):
#         palabra_a_convertir = input('ingrese una palabra: ')
#         palabra_convertida = list(palabra_a_convertir)
#         lista_de_listas.append(palabra_convertida)

#     for impresion in range(len(lista_de_listas)):
#         print(lista_de_listas[impresion])
    
# #llaamar a la funcion
# generador_de_listas_que_estan_dentro_de_otra_lista()

#codigo completo:

def generador_de_listas_que_estan_dentro_de_otra_lista():
    lista_de_listas = []

    for convertir_palabras in range(5):
        palabra_a_convertir = input('ingrese una palabra: ')
        palabra_convertida = list(palabra_a_convertir)
        lista_de_listas.append(palabra_convertida)

    for impresion in range(len(lista_de_listas)):
        print(lista_de_listas[impresion])
        print(type(len(lista_de_listas)))

generador_de_listas_que_estan_dentro_de_otra_lista()
# Out:
# ['h', 'o', 'l', 'a']
# <class 'int'>
# ['q', 'u', 'e', ' ']
# <class 'int'>
# ['t', 'a', 'l']
# <class 'int'>
# ['c', 'o', 'm', 'o']
# <class 'int'>
# ['e', 's', 't', 'a', 's']
# <class 'int'>
